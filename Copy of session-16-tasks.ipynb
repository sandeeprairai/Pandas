# %% [markdown]
# ###`Q-1:` Write a program to create an empty series.

# %%
# code here
import numpy as np
import pandas as pd
# s=pd.DataFrame([]).squeeze(True)
# s
pd.Series()
# Out:
# <ipython-input-15-6ca98eb66470>:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   pd.Series()
# Series([], dtype: float64)

# %% [markdown]
# ###`Q-2:` Write a Pandas program to add, subtract, multiple and divide two Pandas Series.

# %%
# code here
s=pd.DataFrame([12,23,34,45,56,67]).squeeze(True)
p=pd.DataFrame([10.20,30,40,50,60]).squeeze(True)
print(s)
print(p)
print("Here is Addition",s+p)
print("here is Substarction",s-p)
print("Here is multiplication",s*p)
print("Here is division",s/p)
# Out:
# 0    12
# 1    23
# 2    34
# 3    45
# 4    56
# 5    67
# Name: 0, dtype: int64
# 0    10.2
# 1    30.0
# 2    40.0
# 3    50.0
# 4    60.0
# Name: 0, dtype: float64
# Here is Addition 0     22.2
# 1     53.0
# 2     74.0
# 3     95.0
# 4    116.0
# 5      NaN
# Name: 0, dtype: float64
# here is Substarction 0    1.8
# 1   -7.0
# 2   -6.0
# 3   -5.0
# 4   -4.0
# 5    NaN
# Name: 0, dtype: float64
# Here is multiplication 0     122.4
# 1     690.0
# 2    1360.0
# 3    2250.0
# 4    3360.0
# 5       NaN
# Name: 0, dtype: float64
# Here is division 0    1.176471
# 1    0.766667
# 2    0.850000
# 3    0.900000
# 4    0.933333
# 5         NaN
# Name: 0, dtype: float64

# %% [markdown]
# ###`Q-3` Write a Pandas program to compare the elements of the two Pandas Series.
# Sample Series: [2, 4, 6, 8, 10], [1, 3, 5, 7, 10]

# %%
# code here
a=pd.DataFrame([2,4,6,8,10]).squeeze(True)
b=pd.DataFrame([1,3,5,7,10]).squeeze(True)

print(a==b)
print(a<b)
print(a>b)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: 0, dtype: bool
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: 0, dtype: bool
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# Name: 0, dtype: bool

# %% [markdown]
# ###`Q-5.`Write a function to change the data type of given a column or a Series. Function takes series and data type as input, returns the converted series.
# ```
# series = pd.Series([1,2,'Python', 2.0, True, 100])
# change to float type data
# ```
# Note: Read about pd.to_numeric()

# %%
# code here
#Changing the  data type to numeric(int,float)

def change_dtype(series):
  return pd.to_numeric(series, errors='coerce')

series=pd.Series([1,2,'python',2.0,True,100])
change_dtype(series)
# Out:
# 0      1.0
# 1      2.0
# 2      NaN
# 3      2.0
# 4      1.0
# 5    100.0
# dtype: float64

# %% [markdown]
# Download data - https://drive.google.com/file/d/1LRhXwbEodeWXtzPhJCX0X9Lf_BECzvqb/view?usp=share_link
# All Batsman runs series in IPL 2008 to 2022.
#
# Below questions are based on this data.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ###`Q-6` Find top 10 most run getter from the series.

# %%
# code here
data=pd.read_csv( "/content/batsman_runs_series.csv").squeeze(True)
data.sort_values("batsman_run",ascending=False).head(10)
# Out:
#              batter  batsman_run
# 569         V Kohli         6634
# 462        S Dhawan         6244
# 130       DA Warner         5883
# 430       RG Sharma         5881
# 493        SK Raina         5536
# 27   AB de Villiers         5181
# 108        CH Gayle         4997
# 339        MS Dhoni         4978
# 452      RV Uthappa         4954
# 256      KD Karthik         4377

# %% [markdown]
# ###`Q-7` No of players having runs above 3000

# %%
# code here
data[data["batsman_run"]>3000].shape[0]
# Out:
# 20

# %% [markdown]
# ###`Q-8` No of players having runs above mean value?

# %%
# code here
data[data["batsman_run"]> data["batsman_run"].mean()].shape[0]
# Out:
# 128

# %% [markdown]
# Download data - https://drive.google.com/file/d/1QZuZ5bypUInfVvarHACLAi8tXXHvb8xd/view?usp=share_link
#
# file name - items.csv

# %% [markdown]
# ###`Q-9`
#     i. Read `items.csv` making `item_name` as index.
#     ii. Show no of nan values
#     ii. Item price is given in $, so convert it to rupees without currency symbol.
#     iii. Make data type of newly made series as float.
#     iv. Fill nan with mean of the series
#
#
# How csv file looks
#
# ```
# item_name	item_price
# Chips and Fresh Tomato Salsa	$2.39
# Izze	$3.39
# Nantucket Nectar	$3.39
# Chips and Tomatillo-Green Chili Salsa	$2.39
# Chicken Bowl	$16.98
#
# ```

# %%
# code here
#1
items=pd.read_csv("/content/items.csv",index_col=['item_name']).squeeze("columns")
items
# Out:
# item_name
# Chips and Fresh Tomato Salsa              $2.39
# Izze                                      $3.39
# Nantucket Nectar                          $3.39
# Chips and Tomatillo-Green Chili Salsa     $2.39
# Chicken Bowl                             $16.98
#                                           ...
# Steak Burrito                            $11.75
# Steak Burrito                            $11.75
# Chicken Salad Bowl                       $11.25
# Chicken Salad Bowl                        $8.75
# Chicken Salad Bowl                        $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
#show no of nan values
items.isna().sum()
# Out:
# 50

# %%
#2ii
def rupees(x):
  try:
    y=x[1:]
  except:
    #Something Dollar sign is not there which throws an exception
    y=x
  return float(y)*82.49

items.apply(rupees)
# Out:
# item_name
# Chips and Fresh Tomato Salsa              197.1511
# Izze                                      279.6411
# Nantucket Nectar                          279.6411
# Chips and Tomatillo-Green Chili Salsa     197.1511
# Chicken Bowl                             1400.6802
#                                            ...
# Steak Burrito                             969.2575
# Steak Burrito                             969.2575
# Chicken Salad Bowl                        928.0125
# Chicken Salad Bowl                        721.7875
# Chicken Salad Bowl                        721.7875
# Name: item_price, Length: 4622, dtype: float64

# %%
#3
items=items.apply(rupees)
items
# Out:
# item_name
# Chips and Fresh Tomato Salsa              197.1511
# Izze                                      279.6411
# Nantucket Nectar                          279.6411
# Chips and Tomatillo-Green Chili Salsa     197.1511
# Chicken Bowl                             1400.6802
#                                            ...
# Steak Burrito                             969.2575
# Steak Burrito                             969.2575
# Chicken Salad Bowl                        928.0125
# Chicken Salad Bowl                        721.7875
# Chicken Salad Bowl                        721.7875
# Name: item_price, Length: 4622, dtype: float64

# %%
#4
items.fillna(items.mean())
# Out:
# item_name
# Chips and Fresh Tomato Salsa              197.1511
# Izze                                      279.6411
# Nantucket Nectar                          279.6411
# Chips and Tomatillo-Green Chili Salsa     197.1511
# Chicken Bowl                             1400.6802
#                                            ...
# Steak Burrito                             969.2575
# Steak Burrito                             969.2575
# Chicken Salad Bowl                        928.0125
# Chicken Salad Bowl                        721.7875
# Chicken Salad Bowl                        721.7875
# Name: item_price, Length: 4622, dtype: float64

# %%
items.isna().sum()
# Out:
# 50

# %% [markdown]
# ###`Q-10`:
#     i. Find mean price
#     ii. Find 30th and 6th percentile value
#     iii. Plot Histogram on price with bin size 50
#     iv. No of items price lies between [1000 to 2000]

# %%
# code here
#1
items.mean()
# Out:
# 615.6254681102363

# %%
#2
items.quantile(q=0.3)
items.quantile(q=0.06)
# Out:
# 103.1125

# %%
#
items.plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>
